# %%
import logging
import multiprocessing
import os

from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec

# Enable gensim logging
logging.basicConfig(
    format="%(levelname)s - %(asctime)s: %(message)s",
    datefmt="%H:%M:%S",
    level=logging.INFO,
)


class W2VLossLogger(CallbackAny2Vec):
    """Callback to print loss after each epoch
    use by passing model.train(..., callbacks=[W2VLossLogger()])
    """

    def __init__(self):
        self.epoch = 0

    def on_epoch_end(self, model):
        loss = model.get_latest_training_loss()

        if self.epoch == 0:
            print("Loss after epoch {}: {}".format(self.epoch, loss))
        else:
            print(
                "Loss after epoch {}: {}".format(
                    self.epoch, loss - self.loss_previous_step
                )
            )
        self.epoch += 1
        self.loss_previous_step = loss


def train_w2v_model(
    sentences,
    output_file,
    window,
    embedding_dim,
    epochs,
    min_word_count,
):
    

    """Train a word2vec model based on given sentences.
    Args:
        sentences list[list[str]]: List of sentences. Each element contains a list with the words
            in the current sentence
        output_file (str): Path to save the trained w2v model
        window (int): w2v context size
        embedding_dim (int): w2v vector dimension
        epochs (int): How many epochs should the training run
        min_word_count (int): Ignore words that appear less than min_word_count times
    """
    workers = multiprocessing.cpu_count()
    
    # TODO: Instantiate gensim.models.Word2Vec class
    model = Word2Vec(sentences=sentences, vector_size=embedding_dim, window=window, min_count=min_word_count, workers=multiprocessing.cpu_count())
    model.build_vocab(sentences, progress_per=10000)
    # TODO: Build model vocabulary using sentences
    # TODO: Train word2vec model
    model.train(sentences, total_examples=model.corpus_count,epochs=epochs)
    # Save trained model
    model.save(output_file)
    # model.save(output_file)

    

    return model


if __name__ == "__main__":
    # read data/gutenberg.txt in the expected format
    f=open("tokenized.txt","r")
    sentences =eval(f.read())
    
   
    output_file = "gutenberg_w2v.hundd.model"
    window = 5
    embedding_dim = 100
    epochs = 1000
    min_word_count = 1

    gutenberg_w2v =train_w2v_model(
        sentences,
        output_file,
        window,
        embedding_dim,
        epochs,
        min_word_count)
# Out:
# INFO - 10:34:45: collecting all words and their counts
# INFO - 10:34:45: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 10:34:45: PROGRESS: at sentence #10000, processed 113516 words, keeping 6065 word types
# INFO - 10:34:45: PROGRESS: at sentence #20000, processed 227311 words, keeping 8492 word types
# INFO - 10:34:45: PROGRESS: at sentence #30000, processed 324672 words, keeping 9841 word types
# INFO - 10:34:45: PROGRESS: at sentence #40000, processed 427445 words, keeping 11779 word types
# INFO - 10:34:45: PROGRESS: at sentence #50000, processed 537208 words, keeping 13110 word types
# INFO - 10:34:45: PROGRESS: at sentence #60000, processed 647741 words, keeping 14312 word types
# INFO - 10:34:45: PROGRESS: at sentence #70000, processed 751694 words, keeping 16043 word types
# INFO - 10:34:45: PROGRESS: at sentence #80000, processed 847983 words, keeping 16837 word types
# INFO - 10:34:45: PROGRESS: at sentence #90000, processed 957413 words, keeping 17332 word types
# INFO - 10:34:45: PROGRESS: at sentence #100000, processed 1063629 words, keeping 17986 word types
# INFO - 10:34:45: PROGRESS: at sentence #110000, processed 1164106 words, keeping 19045 word types
# INFO - 10:34:45: PROGRESS: at sentence #120000, processed 1276772 words, keeping 21274 word types
# INFO - 10:34:45: PROGRESS: at sentence #130000, processed 1385166 words, keeping 24315 word types
# INFO - 10:34:45: PROGRESS: at sentence #140000, processed 1496887 words, keeping 26028 word types
# INFO - 10:34:45: PROGRESS: at sentence #150000, processed 1613459 words, keeping 27039 word types
# INFO - 10:34:45: PROGRESS: at sentence #160000, processed 1725670 words, keeping 30107 word types
# INFO - 10:34:45: PROGRESS: at sentence #170000, processed 1837438 words, keeping 32790 word types
# INFO - 10:34:45: PROGRESS: at sentence #180000, processed 1920527 words, keeping 34578 word types
# INFO - 10:34:45: PROGRESS: at sentence #190000, processed 1996263 words, keeping 37997 word types
# INFO - 10:34:45: PROGRESS: at sentence #200000, processed 2084641 words, keeping 40487 word types
# INFO - 10:34:45: collected 41465 word types from a corpus of 2135928 raw words and 205767 sentences
# INFO - 10:34:45: Creating a fresh vocabulary
# INFO - 10:34:45: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 41465 unique words (100.00% of original 41465, drops 0)', 'datetime': '2023-04-03T10:34:45.831820', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'prepare_vocab'}
# INFO - 10:34:45: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 2135928 word corpus (100.00% of original 2135928, drops 0)', 'datetime': '2023-04-03T10:34:45.833497', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'prepare_vocab'}
# INFO - 10:34:45: deleting the raw counts dictionary of 41465 items
# INFO - 10:34:45: sample=0.001 downsamples 56 most-common words
# INFO - 10:34:45: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1561117.1381724994 word corpus (73.1%% of prior 2135928)', 'datetime': '2023-04-03T10:34:45.986026', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'prepare_vocab'}
# INFO - 10:34:46: estimated required memory for 41465 words and 100 dimensions: 53904500 bytes
# INFO - 10:34:46: resetting layer weights
# INFO - 10:34:46: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-04-03T10:34:46.286037', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'build_vocab'}
# INFO - 10:34:46: Word2Vec lifecycle event {'msg': 'training model with 8 workers on 41465 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-04-03T10:34:46.286799', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'train'}
# INFO - 10:34:47: EPOCH 0 - PROGRESS: at 95.82% examples, 1498866 words/s, in_qsize 7, out_qsize 2
# INFO - 10:34:47: EPOCH 0: training on 2135928 raw words (1561324 effective words) took 1.0s, 1507932 effective words/s
# INFO - 10:34:48: EPOCH 1 - PROGRESS: at 93.20% examples, 1465268 words/s, in_qsize 13, out_qsize 0
# INFO - 10:34:48: EPOCH 1: training on 2135928 raw words (1561108 effective words) took 1.0s, 1491385 effective words/s
# INFO - 10:34:49: EPOCH 2 - PROGRESS: at 90.58% examples, 1432920 words/s, in_qsize 15, out_qsize 0
# INFO - 10:34:49: EPOCH 2: training on 2135928 raw words (1561277 effective words) took 1.1s, 1444030 effective words/s
# INFO - 10:34:50: EPOCH 3 - PROGRESS: at 95.28% examples, 1489287 words/s, in_qsize 9, out_qsize 0
# INFO - 10:34:50: EPOCH 3: training on 2135928 raw words (1561057 effective words) took 1.0s, 1494951 effective words/s
# INFO - 10:34:51: EPOCH 4: training on 2135928 raw words (1561399 effective words) took 0.8s, 1858985 effective words/s
# INFO - 10:34:51: Word2Vec lifecycle event {'msg': 'training on 10679640 raw words (7806165 effective words) took 5.1s, 1534489 effective words/s', 'datetime': '2023-04-03T10:34:51.374460', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'train'}
# INFO - 10:34:51: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=41465, vector_size=100, alpha=0.025>', 'datetime': '2023-04-03T10:34:51.374829', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'created'}
# INFO - 10:34:51: collecting all words and their counts
# INFO - 10:34:51: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 10:34:51: PROGRESS: at sentence #10000, processed 113516 words, keeping 6065 word types
# INFO - 10:34:51: PROGRESS: at sentence #20000, processed 227311 words, keeping 8492 word types
# INFO - 10:34:51: PROGRESS: at sentence #30000, processed 324672 words, keeping 9841 word types
# INFO - 10:34:51: PROGRESS: at sentence #40000, processed 427445 words, keeping 11779 word types
# INFO - 10:34:51: PROGRESS: at sentence #50000, processed 537208 words, keeping 13110 word types
# INFO - 10:34:51: PROGRESS: at sentence #60000, processed 647741 words, keeping 14312 word types
# INFO - 10:34:51: PROGRESS: at sentence #70000, processed 751694 words, keeping 16043 word types
# INFO - 10:34:51: PROGRESS: at sentence #80000, processed 847983 words, keeping 16837 word types
# INFO - 10:34:51: PROGRESS: at sentence #90000, processed 957413 words, keeping 17332 word types
# INFO - 10:34:51: PROGRESS: at sentence #100000, processed 1063629 words, keeping 17986 word types
# INFO - 10:34:51: PROGRESS: at sentence #110000, processed 1164106 words, keeping 19045 word types
# INFO - 10:34:51: PROGRESS: at sentence #120000, processed 1276772 words, keeping 21274 word types
# INFO - 10:34:51: PROGRESS: at sentence #130000, processed 1385166 words, keeping 24315 word types
# INFO - 10:34:51: PROGRESS: at sentence #140000, processed 1496887 words, keeping 26028 word types
# INFO - 10:34:51: PROGRESS: at sentence #150000, processed 1613459 words, keeping 27039 word types
# INFO - 10:34:51: PROGRESS: at sentence #160000, processed 1725670 words, keeping 30107 word types
# INFO - 10:34:51: PROGRESS: at sentence #170000, processed 1837438 words, keeping 32790 word types
# INFO - 10:34:51: PROGRESS: at sentence #180000, processed 1920527 words, keeping 34578 word types
# INFO - 10:34:51: PROGRESS: at sentence #190000, processed 1996263 words, keeping 37997 word types
# INFO - 10:34:51: PROGRESS: at sentence #200000, processed 2084641 words, keeping 40487 word types
# INFO - 10:34:51: collected 41465 word types from a corpus of 2135928 raw words and 205767 sentences
# INFO - 10:34:51: Creating a fresh vocabulary
# INFO - 10:34:51: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 41465 unique words (100.00% of original 41465, drops 0)', 'datetime': '2023-04-03T10:34:51.792121', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'prepare_vocab'}
# INFO - 10:34:51: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 2135928 word corpus (100.00% of original 2135928, drops 0)', 'datetime': '2023-04-03T10:34:51.792720', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'prepare_vocab'}
# INFO - 10:34:51: deleting the raw counts dictionary of 41465 items
# INFO - 10:34:51: sample=0.001 downsamples 56 most-common words
# INFO - 10:34:51: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1561117.1381724994 word corpus (73.1%% of prior 2135928)', 'datetime': '2023-04-03T10:34:51.955980', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'prepare_vocab'}
# WARNING - 10:34:51: sorting after vectors have been allocated is expensive & error-prone
# INFO - 10:34:52: estimated required memory for 41465 words and 100 dimensions: 53904500 bytes
# INFO - 10:34:52: resetting layer weights
# INFO - 10:34:52: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-04-03T10:34:52.193359', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'build_vocab'}
# WARNING - 10:34:52: Effective 'alpha' higher than previous training cycles
# INFO - 10:34:52: Word2Vec lifecycle event {'msg': 'training model with 8 workers on 41465 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-04-03T10:34:52.194558', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 
words/s, in_qsize 15, out_qsize 0
# INFO - 10:50:16: EPOCH 988: training on 2135928 raw words (1561419 effective words) took 1.5s, 1034549 effective words/s
# INFO - 10:50:17: EPOCH 989 - PROGRESS: at 74.84% examples, 1194617 words/s, in_qsize 15, out_qsize 0
# INFO - 10:50:17: EPOCH 989: training on 2135928 raw words (1560822 effective words) took 1.3s, 1234860 effective words/s
# INFO - 10:50:18: EPOCH 990 - PROGRESS: at 73.95% examples, 1176283 words/s, in_qsize 15, out_qsize 0
# INFO - 10:50:19: EPOCH 990: training on 2135928 raw words (1560998 effective words) took 1.3s, 1233716 effective words/s
# INFO - 10:50:20: EPOCH 991 - PROGRESS: at 78.35% examples, 1253574 words/s, in_qsize 15, out_qsize 0
# INFO - 10:50:20: EPOCH 991: training on 2135928 raw words (1560714 effective words) took 1.2s, 1266559 effective words/s
# INFO - 10:50:21: EPOCH 992 - PROGRESS: at 73.12% examples, 1147624 words/s, in_qsize 16, out_qsize 3
# INFO - 10:50:21: EPOCH 992: training on 2135928 raw words (1560461 effective words) took 1.3s, 1195854 effective words/s
# INFO - 10:50:22: EPOCH 993 - PROGRESS: at 74.84% examples, 1191022 words/s, in_qsize 16, out_qsize 0
# INFO - 10:50:22: EPOCH 993: training on 2135928 raw words (1561377 effective words) took 1.3s, 1217992 effective words/s
# INFO - 10:50:23: EPOCH 994 - PROGRESS: at 75.26% examples, 1201903 words/s, in_qsize 14, out_qsize 1
# INFO - 10:50:24: EPOCH 994: training on 2135928 raw words (1561507 effective words) took 1.3s, 1239100 effective words/s
# INFO - 10:50:25: EPOCH 995 - PROGRESS: at 80.07% examples, 1275157 words/s, in_qsize 14, out_qsize 1
# INFO - 10:50:25: EPOCH 995: training on 2135928 raw words (1560982 effective words) took 1.2s, 1309054 effective words/s
# INFO - 10:50:26: EPOCH 996 - PROGRESS: at 77.01% examples, 1229879 words/s, in_qsize 14, out_qsize 1
# INFO - 10:50:26: EPOCH 996: training on 2135928 raw words (1560451 effective words) took 1.2s, 1258101 effective words/s
# INFO - 10:50:27: EPOCH 997 - PROGRESS: at 78.77% examples, 1249977 words/s, in_qsize 15, out_qsize 0
# INFO - 10:50:27: EPOCH 997: training on 2135928 raw words (1561182 effective words) took 1.2s, 1293040 effective words/s
# INFO - 10:50:28: EPOCH 998 - PROGRESS: at 77.91% examples, 1241328 words/s, in_qsize 14, out_qsize 1
# INFO - 10:50:29: EPOCH 998: training on 2135928 raw words (1560689 effective words) took 1.3s, 1245277 effective words/s
# INFO - 10:50:30: EPOCH 999 - PROGRESS: at 79.21% examples, 1257726 words/s, in_qsize 14, out_qsize 1
# INFO - 10:50:30: EPOCH 999: training on 2135928 raw words (1561203 effective words) took 1.2s, 1321086 effective words/s
# INFO - 10:50:30: Word2Vec lifecycle event {'msg': 'training on 2135928000 raw words (1561123119 effective words) took 938.1s, 1664055 effective words/s', 'datetime': '2023-04-03T10:50:30.338965', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'train'}
# INFO - 10:50:30: Word2Vec lifecycle event {'fname_or_handle': 'gutenberg_w2v.hundd.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2023-04-03T10:50:30.339566', 'gensim': '4.3.1', 'python': '3.10.7 (main, Mar 10 2023, 10:47:39) [GCC 12.2.0]', 'platform': 'Linux-5.19.0-38-generic-x86_64-with-glibc2.36', 'event': 'saving'}
# INFO - 10:50:30: not storing attribute cum_table
# INFO - 10:50:30: saved gutenberg_w2v.hundd.model

# %%
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec

gutenberg_w2v = Word2Vec.load("gutenberg_w2v.hundd.model")

# %%
gutenberg_w2v.wv.most_similar(["bible"])
# Out:
# [('wrist', 0.4070826470851898),
#  ('buzite', 0.3894822895526886),
#  ('dreamer', 0.3729250133037567),
#  ('cobbler', 0.35319337248802185),
#  ('cable', 0.35270583629608154),
#  ('cassius', 0.3514133393764496),
#  ('auger', 0.3499419093132019),
#  ('priesthood', 0.34642016887664795),
#  ('loe', 0.34116289019584656),
#  ('headship', 0.3361479640007019)]

# %%
gutenberg_w2v.wv.most_similar(["book"])
# Out:
# [('xxiii', 0.5053890943527222),
#  ('xxxi', 0.5027292370796204),
#  ('xxix', 0.5025994777679443),
#  ('xxviii', 0.5024734139442444),
#  ('xxv', 0.4990857243537903),
#  ('xxvii', 0.4965112507343292),
#  ('xxvi', 0.4925084710121155),
#  ('raze', 0.490346759557724),
#  ('temple', 0.4875237047672272),
#  ('written', 0.4845070540904999)]

# %%
gutenberg_w2v.wv.most_similar(["bank"])
# Out:
# [('table', 0.5287594199180603),
#  ('wall', 0.5040320754051208),
#  ('ground', 0.5038182735443115),
#  ('top', 0.5032145977020264),
#  ('floor', 0.4864599108695984),
#  ('side', 0.4803113639354706),
#  ('bed', 0.450342059135437),
#  ('hill', 0.4464374780654907),
#  ('river', 0.4414878189563751),
#  ('pool', 0.4404714107513428)]

# %%
gutenberg_w2v.wv.most_similar(["water"])
# Out:
# [('waters', 0.6542330384254456),
#  ('wine', 0.5172027945518494),
#  ('river', 0.5064811110496521),
#  ('hole', 0.49640560150146484),
#  ('fire', 0.4884592294692993),
#  ('wood', 0.4813365340232849),
#  ('rivers', 0.47593218088150024),
#  ('blood', 0.4702102243900299),
#  ('ground', 0.46649661660194397),
#  ('fowls', 0.46397456526756287)]

# %%
v = gutenberg_w2v.wv["good"] - gutenberg_w2v.wv["taller"] + gutenberg_w2v.wv["tall"]
gutenberg_w2v.wv.most_similar(v)
# Out:
# [('good', 0.48668214678764343),
#  ('sandals', 0.4110839068889618),
#  ('tall', 0.40284034609794617),
#  ('tout', 0.3939869999885559),
#  ('festive', 0.37680643796920776),
#  ('handsome', 0.3653698265552521),
#  ('salamander', 0.3586299419403076),
#  ('test', 0.35852161049842834),
#  ('renderest', 0.3573521673679352),
#  ('paire', 0.35532742738723755)]

# %%
v = gutenberg_w2v.wv["grils"] - gutenberg_w2v.wv["kings"] + gutenberg_w2v.wv["queens"]
gutenberg_w2v.wv.most_similar(v)

# %%
v = gutenberg_w2v.wv["france"] - gutenberg_w2v.wv["paris"] + gutenberg_w2v.wv["london"]
gutenberg_w2v.wv.most_similar(v)
# Out:
# [('france', 0.6633819937705994),
#  ('london', 0.5153282284736633),
#  ('inferiorities', 0.39137589931488037),
#  ('plan', 0.3810945153236389),
#  ('highbury', 0.380890429019928),
#  ('species', 0.38061437010765076),
#  ('country', 0.369165301322937),
#  ('siam', 0.3610007166862488),
#  ('allusion', 0.35697129368782043),
#  ('ambassadors', 0.35658982396125793)]

# %%
from gensim.models import KeyedVectors
google_model = KeyedVectors.load_word2vec_format('/home/brewed/Desktop/GoogleNews-vectors-negative300.bin.gz', binary=True,
limit=1000000)

# %%
google_model.most_similar(["bible"])
# Out:
# [('Bible', 0.736778199672699),
#  ('bibles', 0.6052598357200623),
#  ('Holy_Bible', 0.5989601612091064),
#  ('scriptures', 0.574568510055542),
#  ('scripture', 0.5697901844978333),
#  ('New_Testament', 0.5638793110847473),
#  ('Scripture', 0.5502957701683044),
#  ('Scriptures', 0.5411645770072937),
#  ('NRSV', 0.5341106057167053),
#  ('Leviticus_##:##-##', 0.5247005224227905)]

# %%
google_model.most_similar(["book"])
# Out:
# [('tome', 0.7485830783843994),
#  ('books', 0.7379177808761597),
#  ('memoir', 0.7302926778793335),
#  ('paperback_edition', 0.6868364214897156),
#  ('autobiography', 0.6741527318954468),
#  ('memoirs', 0.6505153179168701),
#  ('Book', 0.6479282975196838),
#  ('paperback', 0.6471226811408997),
#  ('novels', 0.6341459155082703),
#  ('hardback', 0.6283079981803894)]

# %%
google_model.most_similar(["bank"])
# Out:
# [('banks', 0.7440759539604187),
#  ('banking', 0.690161406993866),
#  ('Bank', 0.6698698401451111),
#  ('lender', 0.6342284679412842),
#  ('banker', 0.6092953085899353),
#  ('depositors', 0.6031531691551208),
#  ('mortgage_lender', 0.5797975659370422),
#  ('depositor', 0.5716427564620972),
#  ('BofA', 0.5714625120162964),
#  ('Citibank', 0.5589520335197449)]

# %%
google_model.most_similar(["cwater"])
# Out:
# [('coochie', 0.6906902194023132),
#  ('vajayjay', 0.6699857711791992),
#  ('p_*_ssy', 0.6656262278556824),
#  ('tushy', 0.6618760824203491),
#  ('titties', 0.654757022857666),
#  ('d_**_k', 0.6432459950447083),
#  ('Ewwwww', 0.6393193602561951),
#  ('dangly_bits', 0.6388564109802246),
#  ('pubes', 0.6357187628746033),
#  ('Urgh', 0.6354457139968872)]

# %%
v = google_model["girls"] - google_model["queen"] + google_model["kings"]
google_model.most_similar(v)
# Out:
# [('boys', 0.6931698322296143),
#  ('girls', 0.6385126709938049),
#  ('kings', 0.4957888424396515),
#  ('men', 0.48680540919303894),
#  ('teenagers', 0.4788475036621094),
#  ('schoolboys', 0.45804113149642944),
#  ('pee_wees', 0.44774994254112244),
#  ('Mitey_Mite', 0.44012460112571716),
#  ('kids', 0.4373849332332611),
#  ('youngsters', 0.43566834926605225)]

# %%
v = google_model["good"] - google_model["taller"] + google_model["tall"]
google_model.most_similar(v)
# Out:
# [('good', 0.6434131860733032),
#  ('great', 0.49164238572120667),
#  ('bad', 0.4760521948337555),
#  ('terrific', 0.46986129879951477),
#  ('wonderful', 0.4452008605003357),
#  ('nice', 0.4425136148929596),
#  ('fantastic', 0.43418607115745544),
#  ('decent', 0.4307934641838074),
#  ('excellent', 0.41867733001708984),
#  ('terrible', 0.4151829481124878)]

# %%
v = google_model["france"] - google_model["paris"] + google_model["london"]
google_model.most_similar(v)
# Out:
# [('london', 0.754153847694397),
#  ('france', 0.7366582751274109),
#  ('england', 0.600825309753418),
#  ('europe', 0.5708170533180237),
#  ('birmingham', 0.5392330884933472),
#  ('european', 0.5275605916976929),
#  ('newcastle', 0.5263600945472717),
#  ('barcelona', 0.5107599496841431),
#  ('africa', 0.510517418384552),
#  ('spain', 0.5082812905311584)]

# %%
import numpy as np

voc = gutenberg_w2v.wv.index_to_key
# get vector size
dim = gutenberg_w2v.vector_size


# Convert to numpy 2d array (n_vocab x vector_size)
def to_embeddings_Matrix(model):  
    embedding_matrix = np.zeros((len(voc), model.vector_size))
    word2idx = {}
    for i in range(len(voc)):
        embedding_matrix[i] = model.wv[model.wv.index_to_key[i]] 
    return embedding_matrix


embeddings=to_embeddings_Matrix(gutenberg_w2v)
# Out:
# (41465, 100)

# %%
# Put it in data later
import csv
with open('../data/embeddings.tsv', 'w', newline='') as f_output:
    tsv_output = csv.writer(f_output, delimiter='\t')
    for embedding in embeddings:
        tsv_output.writerow(embedding)
    
with open('../data/metadata.tsv', 'w', newline='') as f_output:
    tsv_output = csv.writer(f_output)
    for voc_rows in voc:
        tsv_output.writerow([voc_rows])

# %%
import glob
import os
import re

import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

SCRIPT_DIRECTORY = os.path.realpath(os.getcwd())

data_dir = os.path.join(SCRIPT_DIRECTORY, "../data/aclImdb")
train_dir = os.path.join(data_dir, "train")
test_dir = os.path.join(data_dir, "test")
pos_train_dir = os.path.join(train_dir, "pos")
neg_train_dir = os.path.join(train_dir, "neg")
pos_test_dir = os.path.join(test_dir, "pos")
neg_test_dir = os.path.join(test_dir, "neg")

# For memory limitations. These parameters fit in 8GB of RAM.
# If you have 16G of RAM you can experiment with the full dataset / W2V
MAX_NUM_SAMPLES = 5000
# Load first 1M word embeddings. This works because GoogleNews are roughly
# sorted from most frequent to least frequent.
# It may yield much worse results for other embeddings corpora
NUM_W2V_TO_LOAD = 1000000


SEED = 42

# Fix numpy random seed for reproducibility
np.random.seed(SEED)


def strip_punctuation(s):
    return re.sub(r"[^a-zA-Z\s]", " ", s)


def preprocess(s):
    return re.sub("\s+", " ", strip_punctuation(s).lower())


def tokenize(s):
    return s.split(" ")


def preproc_tok(s):
    return tokenize(preprocess(s))


def token_proc(t_corpus):
    data=[]
    for i,ind in enumerate(t_corpus):
        proc_t_corpus=preproc_tok(train_corpus[i])
        data.append(proc_t_corpus)
    
    return data


# def read_samples(folder, preprocess=lambda x: x):
#     samples = glob.iglob(os.path.join(folder, "*.txt"))
#     data = []

#     for i, sample in enumerate(samples):
#         if MAX_NUM_SAMPLES > 0 and i == MAX_NUM_SAMPLES:
#             break
#         with open(sample, "r") as fd:
#             x = [preprocess(l) for l in fd][0]
#             data.append(x)

#     return data


def create_corpus(pos, neg):
    corpus = np.array(pos + neg)
    y = np.array([1 for _ in pos] + [0 for _ in neg])
    indices = np.arange(y.shape[0])
    np.random.shuffle(indices)

    return list(corpus[indices]), list(y[indices])


def extract_nbow(corpus):
    """Extract neural bag of words representations"""
    freq = {}
    for item in corpus:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1
 

    return freq

    raise NotImplementedError("Implement nbow extractor")


def train_sentiment_analysis(train_corpus, train_labels):
    """Train a sentiment analysis classifier using NBOW + Logistic regression"""
    raise NotImplementedError("Implement sentiment analysis training")


def evaluate_sentiment_analysis(classifier, test_corpus, test_labels):
    """Evaluate classifier in the test corpus and report accuracy"""
    raise NotImplementedError("Implement sentiment analysis evaluation")


if __name__ == "__main__":
    # TODO: read Imdb corpus
    pos_train=read_samples(pos_train_dir)
    neg_train=read_samples(neg_train_dir)
    
    
    pos_test=read_samples(pos_test_dir)
    neg_test=read_samples(neg_test_dir)
    
    corpus,labels = create_corpus(pos_train,neg_train)
#     train_corpus, train_labels = create_corpus(pos_train,neg_train)
#     test_corpus, test_labels = create_corpus(pos_test,neg_test)
#     nbow_corpus = extract_nbow(corpus)
    (
            train_corpus,
            test_corpus,
            train_labels,
            test_labels,
    ) = sklearn.model_selection.train_test_split(corpus, labels)
#         p_corpus=extract_nbow(corpus)
        # TODO: train / evaluate and report accuracy

# %%
def token_proc(t_corpus):
    data=[]
    for i,ind in enumerate(t_corpus):
        proc_t_corpus=preproc_tok(train_corpus[i])
        data.append(proc_t_corpus)
    
    return data
        
        

proc_train_corpus=token_proc(train_corpus)

# %%
# print(proc_train_corpus[1])

# %%
# print(extract_nbow(proc_train_corpus[1]))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf=TfidfVectorizer(strip_accents=None,lowercase=False,preprocessor=None,tokenizer=token_proc,use_idf=True,norm='l2',smooth_idf=True)

# %%
import pandas as pd


df = pd.DataFrame (corpus)
df.columns=['text']
df.insert(1, "label", labels, True)
print(df)
# Out:
#                                                    text  label
# 0     Over the last 20 years the majority of British...      0
# 1     The plot intellect is about as light as feathe...      1
# 2     Personnaly I really loved this movie, and it p...      1
# 3     I've just purchased the restored version of a ...      1
# 4     ''Ranma ½" is my favorite anime by Rumiko Taka...      1
# ...                                                 ...    ...
# 9995  to be honest, i didn't watch all of the origin...      0
# 9996  It is enjoyable and fast-paced. <br /><br />Th...      0
# 9997  If this movie were any worse, it would have be...      0
# 9998  Turned out to be a classy production with what...      1
# 9999  A shaky hand-held camera was used, presumably ...      0
#
# [10000 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
y=df.label.values
count=CountVectorizer()

# corpus_list=[[i] for i in corpus]
# print(corpus_list[0])
# print(token_proc(corpus))
x=count.fit_transform(df.text)
# print(y)
# # tfidf.get_feature_names_out()
# print(count.get_feature_names())

# %%
 (
            train_corpus,
            test_corpus,
            train_labels,
            test_labels,
    ) = sklearn.model_selection.train_test_split(df.text, df.label)
#         p_corpus=extract_nbow(corpus)

# %%
print(train_corpus)
# Out:
# 4143    This remake of the 1962 orginal film'o the boo...
# 6934    An idiotic dentist finds out that his wife has...
# 5777    This movie is about a female rape victim/comic...
# 5586    on the contrary to the person listed above me ...
# 2591    Holy crap! What a terrible, terrible Spanish t...
#                               ...
# 7087    Saw in on TV late last night. Yeah, I can hear...
# 5629    I am dumbfounded that I actually sat and watch...
# 4139    According to IMDb Takashi Miike's Master of Ho...
# 7944    I swear when I first saw this movie,I cried my...
# 2156    The story of Cinderella is one of my favorites...
# Name: text, Length: 7500, dtype: object

# %%
from sklearn.linear_model import LogisticRegressionCV

clf=LogisticRegressionCV(cv=5,scoring='accuracy',random_state=42,n_jobs=-1,verbose=3,max_iter=500).fit(train_corpus,train_corpus)

y_pred = clf.predict(test_corpus)
